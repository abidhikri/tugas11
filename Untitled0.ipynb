# %% [markdown]
# <a href="https://colab.research.google.com/github/abidhikri/tugas11/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# TUGAS 13
#
# GRAFIK 1800

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def cos(frek,tipe,ht,hr,d):
    if frek in range(150,1501):
        Ca=69.55
        Cb=26.16
    elif frek in range(1501,2001):
        Ca=46.3
        Cb=33.9
    
    if tipe=='urban' :
        Cm=0
    elif tipe=='suburban' :
        Cm= -2*((np.log10((frek/28)**2))-5.4)
    elif tipe=='open' :
        Cm= -4.78*(np.log10(frek))+18.33*(np.log10(frek))-40.94
    else :
        Cm='tipe salah'
    
    ahr = (1.1*np.log10(frek)-0.7)*hr-(1.56*np.log10(frek)-1.8)
    Lp = Ca+(Cb*np.log10(frek))-(13.83*np.log(ht))-ahr+((44.9-6.55*np.log10(ht))*np.log10(d))-Cm
    
    return Lp

# %%
f=1800 #MHz
zona='urban'
zona2='suburban'
zona3='open'
tower=80 #m
user=1.5 #m
dmin=200 #m
dmax=700 #m
N=200 #titik
d=np.random.randint(dmin,dmax,N)

# %%
print(d)
# Out:
# [508 366 317 318 277 581 339 637 677 248 353 589 231 292 557 262 644 613
#  242 266 665 333 214 595 426 570 336 377 494 429 425 599 361 347 487 497
#  216 663 283 699 540 365 286 635 636 384 283 423 377 633 509 616 494 473
#  310 365 457 636 335 442 292 554 258 637 446 211 485 275 597 591 469 328
#  664 290 614 324 417 252 465 346 356 458 506 368 499 583 573 628 331 664
#  554 415 522 229 353 286 585 213 284 679 291 364 221 521 534 593 444 320
#  449 382 584 669 444 459 548 650 398 287 527 597 456 304 616 469 408 643
#  285 463 652 547 201 287 558 617 384 530 290 494 401 243 460 242 545 288
#  231 657 686 470 444 389 210 259 691 211 579 517 582 559 698 510 294 379
#  423 223 392 428 639 608 335 424 266 483 455 260 566 210 260 689 377 458
#  612 345 319 336 615 494 252 561 500 524 378 250 622 563 471 332 570 478
#  215 658]

# %%
LpUrban=cos(f,zona,tower,user,d)
LpSuburban=cos(f,zona2,tower,user,d)
LpOpen=cos(f,zona3,tower,user,d)

# %%
d_sort=d[np.argsort(d)]
Urban_sort=LpUrban[np.argsort(d)]
Suburban_sort=LpSuburban[np.argsort(d)]
Open_sort=LpOpen[np.argsort(d)]

# %%
plt.figure()
plt.plot(d_sort,Urban_sort,'r-', label='Urban')
plt.plot(d_sort,Suburban_sort,'k-', label='Suburban')
plt.plot(d_sort,Open_sort,'g-', label='Open')
plt.legend()
plt.title('Frekuensi 1800 MHz')
plt.xlabel('Jarak (m)')
plt.ylabel('Path Loss (dB)')
plt.show()

# %% [markdown]
# GRAFIK URBAN

# %%
f=700 #MHz
f2=900 #MHz
f3=1800 #MHz
zona='urban'
tower=80 #m
user=1.5 #m
dmin=200 #m
dmax=700 #m
N=200 #titik
d=np.random.randint(dmin,dmax,N)

# %%
LpUrban=cos(f,zona,tower,user,d)
LpUrban2=cos(f2,zona,tower,user,d)
LpUrban3=cos(f3,zona,tower,user,d)

# %%
d_sort=d[np.argsort(d)]
Urban_sort=LpUrban[np.argsort(d)]
Urban2_sort=LpUrban2[np.argsort(d)]
Urban3_sort=LpUrban3[np.argsort(d)]

# %%
plt.figure()
plt.plot(d_sort,Urban_sort,'r-', label='700 Mhz')
plt.plot(d_sort,Urban2_sort,'k-', label='900 Mhz')
plt.plot(d_sort,Urban3_sort,'g-', label='1800 Mhz')
plt.legend()
plt.title('Model Urban')
plt.xlabel('Jarak (m)')
plt.ylabel('Path Loss (dB)')
plt.show()
